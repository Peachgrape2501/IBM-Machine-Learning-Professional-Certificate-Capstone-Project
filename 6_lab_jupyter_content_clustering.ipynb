# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML321ENSkillsNetwork817-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Clustering based Course Recommender System**

# %% [markdown]
# Estimated time needed: **90** minutes

# %% [markdown]
# Previously, we have generated user profile vectors based on course ratings and genres.
#
# A user profile vector may look like a row vector in the following matrix, for example, we can see the Database column for user2 has a value 1 which means user2 is very interesting in courses related to the databases. With the user profile vectors generated, we can also easily compute the similarity among users based on their shared interests.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/userprofiles.png)

# %% [markdown]
# Furthermore, we could perform clustering algorithms such as K-means or DBSCAN to group users with similar learning interests. For example, in the below user clusters, we have user clusters whom have learned courses related to machine learning, cloud computing, databases, and web development, etc.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/userprofiles_clustering.png)

# %% [markdown]
# For each user group, we can come up with a list of popular courses. For example, for the machine learning user cluster/learning group, we can count the most frequently enrolled courses, which are very likely to be the most popular and good machine learning courses because they are enrolled by many users who are interested in machine learning.
#
# If we know a user belongs to the machine learning group, we may recommend the most enrolled courses to them and it is very likely the user will be interested in them.

# %% [markdown]
# Next in this lab, you will be implementing some clustering-based recommender system algorithms.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# * Perform k-means clustering on the original user profile feature vectors
# * Apply PCA (Principle Component Analysis ) on user profile feature vectors to reduce dimensions
# * Perform k-means clustering on the PCA transformed main components
# * Generate course recommendations based on other group members' enrollment history

# %% [markdown]
# ----

# %% [markdown]
# ## Prepare and setup lab environment

# %% [markdown]
# First install and import required libraries:

# %%
# %pip install scikit-learn
# %pip install seaborn
# %pip install pandas
# %pip install matplotlib
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy>=1.19.5 (from scikit-learn)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 7.7 MB/s eta 0:00:00
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 9.2 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 122.9 MB/s eta 0:00:0000:010:01
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 41.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 103.9 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 76.5 MB/s eta 0:00:00:00:0100:01
# Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
# Successfully installed joblib-1.4.0 numpy-1.26.4 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.4.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.11/site-packages (from seaborn) (1.26.4)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.8.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.51.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 23.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pillow-10.3.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Collecting tzdata>=2022.7 (from pandas>=1.2->seaborn)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 37.1 MB/s eta 0:00:00
# Downloading matplotlib-3.8.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 117.4 MB/s eta 0:00:0000:010:01
# Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 114.6 MB/s eta 0:00:0000:010:01
# Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 39.5 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 107.8 MB/s eta 0:00:0000:01
# Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 82.9 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 112.2 MB/s eta 0:00:0000:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 13.3 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 39.2 MB/s eta 0:00:00
# Installing collected packages: tzdata, pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, pandas, matplotlib, seaborn
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.8.4 pandas-2.2.2 pillow-10.3.0 pyparsing-3.1.2 seaborn-0.13.2 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %matplotlib inline

# %%
# also set a random state
rs = 123

# %% [markdown]
# ### Load the user profile dataset

# %% [markdown]
# Let's first load the original user profile feature vectors:

# %%
# Importing the pandas library, which is commonly used for data manipulation and analysis
import pandas as pd

# Defining the URL of the CSV file containing user profiles
user_profile_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/user_profile.csv"

# Using pandas' read_csv function to read the CSV file from the specified URL into a DataFrame
user_profile_df = pd.read_csv(user_profile_url)

# Displaying the first few rows of the DataFrame to inspect its contents
user_profile_df.head()
# Out:
#    user  Database  Python  CloudComputing  DataAnalysis  Containers  \
# 0     2      52.0    14.0             6.0          43.0         3.0
# 1     4      40.0     2.0             4.0          28.0         0.0
# 2     5      24.0     8.0            18.0          24.0         0.0
# 3     7       2.0     0.0             0.0           2.0         0.0
# 4     8       6.0     0.0             0.0           4.0         0.0
#
#    MachineLearning  ComputerVision  DataScience  BigData  Chatbot     R  \
# 0             33.0             0.0         29.0     41.0      2.0  18.0
# 1             14.0             0.0         20.0     24.0      0.0   6.0
# 2             30.0             0.0         22.0     14.0      2.0  14.0
# 3              0.0             0.0          0.0      2.0      0.0   0.0
# 4              0.0             0.0          0.0      6.0      0.0   2.0
#
#    BackendDev  FrontendDev  Blockchain
# 0        34.0          9.0         6.0
# 1         6.0          0.0         2.0
# 2        26.0          4.0         6.0
# 3         0.0          0.0         0.0
# 4         0.0          0.0         0.0

# %%
user_profile_df.shape
# Out:
# (33901, 15)

# %% [markdown]
# we can then list the feature names, they are the user interested topics (course genres):

# %%
feature_names = list(user_profile_df.columns[1:])
feature_names
# Out:
# ['Database',
#  'Python',
#  'CloudComputing',
#  'DataAnalysis',
#  'Containers',
#  'MachineLearning',
#  'ComputerVision',
#  'DataScience',
#  'BigData',
#  'Chatbot',
#  'R',
#  'BackendDev',
#  'FrontendDev',
#  'Blockchain']

# %% [markdown]
# As we can see from the user profile dataset, we have about 33K unique users with interests in areas like ``Database``, ``Python``, ``CloudComputing``, etc. Then, let's check the  summary statistics for each feature.

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  33901.000000  33901.000000    33901.000000  33901.000000
# mean   1.064064e+06      5.518569      3.493791        2.307100      3.624701
# std    4.972578e+05      7.611941      4.227254        3.841858      4.760135
# min    2.000000e+00      0.000000      0.000000        0.000000      0.000000
# 25%    6.813480e+05      0.000000      0.000000        0.000000      0.000000
# 50%    1.043907e+06      3.000000      3.000000        0.000000      3.000000
# 75%    1.451159e+06      9.000000      6.000000        3.000000      6.000000
# max    2.103039e+06     63.000000     18.000000       38.000000     48.000000
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  33901.000000     33901.000000    33901.000000  33901.000000
# mean       0.998938         3.048022        0.001770      5.087343
# std        2.351764         4.624004        0.072846      5.230697
# min        0.000000         0.000000        0.000000      0.000000
# 25%        0.000000         0.000000        0.000000      0.000000
# 50%        0.000000         0.000000        0.000000      3.000000
# 75%        0.000000         3.000000        0.000000      9.000000
# max       15.000000        39.000000        3.000000     32.000000
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  33901.000000  33901.000000  33901.000000  33901.000000  33901.000000
# mean       4.750450      0.462995      1.017433      2.269461      0.315802
# std        7.216228      1.055186      2.342532      4.310752      1.363462
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        2.000000      0.000000      0.000000      0.000000      0.000000
# 75%        6.000000      0.000000      0.000000      3.000000      0.000000
# max       54.000000      6.000000     18.000000     54.000000     15.000000
#
#          Blockchain
# count  33901.000000
# mean       0.986844
# std        1.950585
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max       12.000000

# %% [markdown]
# The original user profile feature vector is not normalized, which may cause issues when we perform clustering and Principal component analysis (PCA), therefor we standardize the data.

# %%
# Use StandardScaler to make each feature with mean 0, standard deviation 1
# Instantiating a StandardScaler object
scaler = StandardScaler()

# Standardizing the selected features (feature_names) in the user_profile_df DataFrame
user_profile_df[feature_names] = scaler.fit_transform(user_profile_df[feature_names])

# Printing the mean and standard deviation of the standardized features
print("mean {} and standard deviation{} ".format(user_profile_df[feature_names].mean(), user_profile_df[feature_names].std()))
# Out:
# mean Database          -3.353495e-17
# Python            -5.700942e-17
# CloudComputing    -3.521170e-17
# DataAnalysis      -7.671120e-17
# Containers         3.353495e-18
# MachineLearning    3.688845e-17
# ComputerVision    -1.509073e-17
# DataScience       -1.676748e-17
# BigData            6.706990e-17
# Chatbot           -6.874665e-17
# R                  4.233788e-17
# BackendDev         1.383317e-17
# FrontendDev        5.051202e-17
# Blockchain        -5.281755e-17
# dtype: float64 and standard deviationDatabase           1.000015
# Python             1.000015
# CloudComputing     1.000015
# DataAnalysis       1.000015
# Containers         1.000015
# MachineLearning    1.000015
# ComputerVision     1.000015
# DataScience        1.000015
# BigData            1.000015
# Chatbot            1.000015
# R                  1.000015
# BackendDev         1.000015
# FrontendDev        1.000015
# Blockchain         1.000015
# dtype: float64

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  3.390100e+04  3.390100e+04    3.390100e+04  3.390100e+04
# mean   1.064064e+06 -3.353495e-17 -5.700942e-17   -3.521170e-17 -7.671120e-17
# std    4.972578e+05  1.000015e+00  1.000015e+00    1.000015e+00  1.000015e+00
# min    2.000000e+00 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 25%    6.813480e+05 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 50%    1.043907e+06 -3.308757e-01 -1.168130e-01   -6.005256e-01 -1.312380e-01
# 75%    1.451159e+06  4.573712e-01  5.928781e-01    1.803581e-01  4.990056e-01
# max    2.103039e+06  7.551593e+00  3.431642e+00    9.290667e+00  9.322416e+00
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  3.390100e+04     3.390100e+04    3.390100e+04  3.390100e+04
# mean   3.353495e-18     3.688845e-17   -1.509073e-17 -1.676748e-17
# std    1.000015e+00     1.000015e+00    1.000015e+00  1.000015e+00
# min   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 25%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 50%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -3.990622e-01
# 75%   -4.247674e-01    -1.038556e-02   -2.429612e-02  7.480294e-01
# max    5.953517e+00     7.775190e+00    4.115884e+01  5.145214e+00
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04
# mean   6.706990e-17 -6.874665e-17  4.233788e-17  1.383317e-17  5.051202e-17
# std    1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00
# min   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 25%   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 50%   -3.811535e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 75%    1.731609e-01 -4.387873e-01 -4.343370e-01  1.694715e-01 -2.316212e-01
# max    6.824934e+00  5.247500e+00  7.249771e+00  1.200053e+01  1.076995e+01
#
#          Blockchain
# count  3.390100e+04
# mean  -5.281755e-17
# std    1.000015e+00
# min   -5.059295e-01
# 25%   -5.059295e-01
# 50%   -5.059295e-01
# 75%    5.194189e-01
# max    5.646161e+00

# %% [markdown]
# The normalized user profile features are:

# %%
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
features
# Out:
#        Database    Python  CloudComputing  DataAnalysis  Containers  \
# 0      6.106474  2.485388        0.961242      8.272010    0.850889
# 1      4.529980 -0.353377        0.440653      5.120792   -0.424767
# 2      2.427988  1.066006        4.084776      4.280467   -0.424767
# 3     -0.462250 -0.826504       -0.600526     -0.341319   -0.424767
# 4      0.063248 -0.826504       -0.600526      0.078843   -0.424767
# ...         ...       ...             ...           ...         ...
# 33896 -0.330876 -0.116813        0.180358      0.499006   -0.424767
# 33897 -0.724999 -0.826504       -0.079936     -0.761482   -0.424767
# 33898 -0.330876  0.592878        0.961242     -0.761482   -0.424767
# 33899 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
# 33900 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
#
#        MachineLearning  ComputerVision  DataScience   BigData   Chatbot  \
# 0             6.477594       -0.024296     4.571668  5.023412  1.456642
# 1             2.368540       -0.024296     2.851031  2.667576 -0.438787
# 2             5.828796       -0.024296     3.233395  1.281790  1.456642
# 3            -0.659184       -0.024296    -0.972608 -0.381153 -0.438787
# 4            -0.659184       -0.024296    -0.972608  0.173161 -0.438787
# ...                ...             ...          ...       ...       ...
# 33896        -0.659184       -0.024296     0.174484 -0.658311 -0.438787
# 33897        -0.659184       -0.024296    -0.972608 -0.658311 -0.438787
# 33898         2.368540       -0.024296     0.748029 -0.658311 -0.438787
# 33899        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
# 33900        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
#
#               R  BackendDev  FrontendDev  Blockchain
# 0      7.249771    7.360899     6.369323    2.570116
# 1      2.127032    0.865416    -0.231621    0.519419
# 2      5.542191    5.505047     2.702132    2.570116
# 3     -0.434337   -0.526473    -0.231621   -0.505930
# 4      0.419453   -0.526473    -0.231621   -0.505930
# ...         ...         ...          ...         ...
# 33896  2.127032    0.865416    -0.231621    1.032093
# 33897 -0.434337   -0.526473    -0.231621   -0.505930
# 33898  0.846348   -0.526473    -0.231621   -0.505930
# 33899 -0.434337   -0.526473    -0.231621   -0.505930
# 33900 -0.434337   -0.526473    -0.231621   -0.505930
#
# [33901 rows x 14 columns]

# %% [markdown]
# we can also save the user ids for later recommendation tasks:

# %%
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']
user_ids
# Out:
#           user
# 0            2
# 1            4
# 2            5
# 3            7
# 4            8
# ...        ...
# 33896  2102054
# 33897  2102356
# 33898  2102680
# 33899  2102983
# 33900  2103039
#
# [33901 rows x 1 columns]

# %% [markdown]
# ### TASK: Perform K-means clustering algorithm on the user profile feature vectors

# %% [markdown]
# With the user profile dataset ready, you need to use the `KMeans` class provided by scikit-learn library to perform clustering on the user profile feature vectors.

# %% [markdown]
# For `KMeans` algorithm, one important hyperparameter is the number of clusters `n_cluster`, and a good way to find the optimized `n_cluster` is using to grid search a list of candidates and find the one with the best or optimized clustering evaluation metrics such as minimal `sum of squared distance`:

# %% [markdown]
# _TODO: grid search the optimized n_cluster for KMeans() model_

# %%
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt

# %%
# WRITE YOUR CODE HERE

# Find an optimized number of neighors k from a candidate list such as list_k = list(range(1, 30))

distorsions = []
for k in range(1, 30):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(features)
    distorsions.append(kmeans.inertia_)

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(range(1, 30), distorsions)
plt.grid(True)
plt.title('Elbow curve')
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# Create a list that will hold the the sum of square distances for each fitted model. For each k in `n_clusters` make a model by calling `KMeans(n_clusters=k, random_state=rs).fit(features)` ans append `model.inertia_` to the list. Plot square distances against the k values.
#
# </details>

# %% [markdown]
# If you plot the grid search process, you may get a elbow plot like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/clusters_elbow.png)

# %% [markdown]
# From the elbow plot, you should visualy identify the point where the metric starting to be flatten, which indicates the optimized number of clusters.

# %% [markdown]
# Once you have identified the best number of clusters, you can apply `KMeans()` again to generate cluster label for all users.

# %%
cluster_labels = [None] * len(user_ids)

# %%
cluster_labels = kmeans.labels_
cluster_labels.shape
# Out:
# (33901,)

# %% [markdown]
# _TODO: Apply KMeans() on the features with optimized n_cluster parameter after model fitting, you can find output cluster labels in `model.labels_` attribute_

# %%
def combine_cluster_labels(user_ids, labels):
    # Convert labels to a DataFrame
    labels_df = pd.DataFrame(labels)    
    # Merge user_ids DataFrame with labels DataFrame based on index
    cluster_df = pd.merge(user_ids, labels_df, left_index=True, right_index=True)
    # Rename columns to 'user' and 'cluster'
    cluster_df.columns = ['user', 'cluster']
    return cluster_df

# %%
combine_cluster_labels(user_ids, cluster_labels)
# Out:
#           user  cluster
# 0            2       15
# 1            4       15
# 2            5       14
# 3            7       11
# 4            8       11
# ...        ...      ...
# 33896  2102054        1
# 33897  2102356       11
# 33898  2102680       23
# 33899  2102983       11
# 33900  2103039       11
#
# [33901 rows x 2 columns]

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# Create  a model by calling `KMeans(n_clusters=k, random_state=rs).fit(features)`. Save the labels by accessing `model.labels`.
#
# </details>

# %% [markdown]
# The cluster labels you generated is a list of integers indicating cluster indices. You may use the following utility method to combine the cluster labels and user ids to a dataframe, so that you know which cluster a user belongs:

# %% [markdown]
# Your clustering results may look like the following screenshot:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/cluster_labels.png)

# %% [markdown]
# Now, each user finds its own cluster or we can say we have created many clusters of learning communities. Learners within each community share very similar learning interests.

# %% [markdown]
# ### TASK: Apply PCA on user profile feature vectors to reduce dimensions

# %% [markdown]
# In the previous step, we applied `KMeans` on the original user profile feature vectors which have 14 original features (the course genres).

# %%
# Extracting features from the user_profile_df DataFrame, excluding the 'user' column
features = user_profile_df.loc[:, user_profile_df.columns != 'user']

# Extracting user IDs from the user_profile_df DataFrame
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']

# Creating a list of feature names by excluding the 'user' column name
feature_names = list(user_profile_df.columns[1:])

# %%
print(f"There are {len(feature_names)} features for each user profile.")
# Out:
# There are 14 features for each user profile.

# %% [markdown]
# If we plot a covariance matrix of the user profile feature vectors with 14 features, we can observe that some features are actually correlated:

# %%
sns.set_theme(style="white")

# Compute the correlation matrix
corr = features.cov()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})


plt.show()

# %% [markdown]
# For example, the feature `MachineLearning` and the feature `DataScience` are correlated. Such covariances among features may indicate that we can apply PCA to find its main components (eigenvectors with max eigenvalues on the covariance matrix).
#
# If we only keep the independent main components, then we can reduce the dimensions of our user profile feature vectors.

# %% [markdown]
# Now let's apply the `PCA()` provided by  `scikit-learn` to find the main components in user profile feature vectors and see if we can reduce its dimensions by only keeping the main components.

# %% [markdown]
# Note that when calling the  `PCA()` class, there is also an import argument called `n_components` which indicates how many components you want to keep in the PCA result. One way to find an optimized `n_components` is to do a grid search on a list of argument candidates (such as `range(1, 15)`) and calculate the ratio of the accumulated variance for each candidate.
#
# If the accumulated variances ratio of a candidate `n_components` is larger than a threshold, e.g., 90%, then we can say the transformed `n_components` could explain about 90% of variances of the original data variance and can be considered as an optimized components size.

# %% [markdown]
# _TODO: Find the optimized `n_components` for PCA_

# %%
from sklearn.decomposition import PCA

# %%
# WRITE YOUR CODE HERE

# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio
accVarRatio = []

for n_components in range(1, 15):
    pca = PCA(n_components=n_components)
    pca.fit(features)

    print(pca.explained_variance_ratio_.sum())
    print(pca.singular_values_)

    accVarRatio.append(pca.explained_variance_ratio_.sum())
# Out:
# 0.28756843387699715
# [369.43741645]
# 0.46309256448040315
# [369.43741645 288.6281513 ]
# 0.5761339643675617
# [369.43741645 288.6281513  231.62692194]
# 0.6487465627832345
# [369.43741645 288.6281513  231.62692194 185.64200975]
# 0.7194878762997218
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477]
# 0.7882103410314044
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592]
# 0.8429558465572841
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997]
# 0.8944445500368894
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282]
# 0.9272695591307683
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107]
# 0.9544658170614706
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107 113.61216819]
# 0.9733572103164764
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107 113.61216819
#   94.68959667]
# 0.9870310843021104
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107 113.61216819
#   94.68959667  80.55936958]
# 0.997916316661769
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107 113.61216819
#   94.68959667  80.55936958  71.87686464]
# 0.9999999999999999
# [369.43741645 288.6281513  231.62692194 185.64200975 183.23432477
#  180.60078592 161.19237997 156.32421282 124.81670107 113.61216819
#   94.68959667  80.55936958  71.87686464  31.44750044]

# %%
plot_df = pd.DataFrame({'n_component': range(1, 15), 'accumulated variance ratio': accVarRatio})
sns.barplot(x='n_component', y='accumulated variance ratio', data=plot_df)
# Out:
# <Axes: xlabel='n_component', ylabel='accumulated variance ratio'>

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * For each `n_components` from 1 to 14 you can call `PCA=PCA(n_components=component)`, then you can simply fit it by callsing `pca.fit_transform(features)` where `features = user_profile_df.loc[:, user_profile_df.columns != 'user']`.
# * Then you can find `accumulated_variance_ratios` by applying `sum()` to `pca.explained_variance_ratio_`.
# * Then find the smallest n_components value for which `accumulated_variance_ratios >= 0.9` and return it.
# </details>

# %% [markdown]
# If you visualize your hyperparameter searching process, you may get a trend line like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/pca.png)

# %% [markdown]
# Once you found the optimized `n_component` argument value, you can apply PCA on the user profile feature vectors and reduce the  14 features into  `n_component` features.

# %% [markdown]
# _TODO: Perform PCA to transform original user profile features_

# %%
# WRITE YOUR CODE HERE

# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio
# - Merge the user ids and transformed features into a new dataframe
for i in range(len(accVarRatio)):
    if accVarRatio[i] > 0.9:
        print(i)
# Out:
# 8
# 9
# 10
# 11
# 12
# 13

# %%
pca = PCA(n_components=9)
pca.fit(features)
transformed_features = pca.transform(features)
print(transformed_features)
# Out:
# [[17.77249439  0.20068141  1.73060927 ...  0.681042    2.31261304
#    0.86827151]
#  [ 7.14519863 -2.84748121  2.3586356  ...  0.54976933  0.46903346
#    0.03340487]
#  [11.36326985  1.8736192  -1.52207738 ...  1.67758234  2.9376687
#    2.09763858]
#  ...
#  [ 0.62594328 -0.54716673 -1.69282423 ... -0.05509971  0.58209105
#    1.70319253]
#  [-2.03683187 -0.15353383  0.16285226 ...  0.07249638  0.11374975
#    0.62289958]
#  [-2.03683187 -0.15353383  0.16285226 ...  0.07249638  0.11374975
#    0.62289958]]

# %%
new_df = pd.DataFrame(transformed_features)
new_df
# Out:
#                0         1         2         3         4         5         6  \
# 0      17.772494  0.200681  1.730609  2.567359 -3.825814  2.707154  0.681042
# 1       7.145199 -2.847481  2.358636 -0.576654  0.398803 -0.134533  0.549769
# 2      11.363270  1.873619 -1.522077  1.076144 -1.711688  0.883212  1.677582
# 3      -1.834033 -0.277462  0.564905  0.053470 -0.064440  0.165757  0.030956
# 4      -1.049125 -0.684767  1.072765  0.006371 -0.005695  0.118686  0.118559
# ...          ...       ...       ...       ...       ...       ...       ...
# 33896   0.633824  0.108815 -0.388871 -0.122665 -0.098364  0.358333  1.752049
# 33897  -2.095339  0.135058  0.244727 -0.088185  0.025081  0.183641  0.046413
# 33898   0.625943 -0.547167 -1.692824 -0.630589  0.166632  0.676244 -0.055100
# 33899  -2.036832 -0.153534  0.162852  0.082651 -0.126419  0.255109  0.072496
# 33900  -2.036832 -0.153534  0.162852  0.082651 -0.126419  0.255109  0.072496
#
#               7         8
# 0      2.312613  0.868272
# 1      0.469033  0.033405
# 2      2.937669  2.097639
# 3      0.039519  0.210887
# 4      0.559292  0.186379
# ...         ...       ...
# 33896  1.486542 -0.523600
# 33897  0.191709  0.260437
# 33898  0.582091  1.703193
# 33899  0.113750  0.622900
# 33900  0.113750  0.622900
#
# [33901 rows x 9 columns]

# %%
new_df.insert(0, "user", user_ids, True)

# %%
new_df
# Out:
#           user          0         1         2         3         4         5  \
# 0            2  17.772494  0.200681  1.730609  2.567359 -3.825814  2.707154
# 1            4   7.145199 -2.847481  2.358636 -0.576654  0.398803 -0.134533
# 2            5  11.363270  1.873619 -1.522077  1.076144 -1.711688  0.883212
# 3            7  -1.834033 -0.277462  0.564905  0.053470 -0.064440  0.165757
# 4            8  -1.049125 -0.684767  1.072765  0.006371 -0.005695  0.118686
# ...        ...        ...       ...       ...       ...       ...       ...
# 33896  2102054   0.633824  0.108815 -0.388871 -0.122665 -0.098364  0.358333
# 33897  2102356  -2.095339  0.135058  0.244727 -0.088185  0.025081  0.183641
# 33898  2102680   0.625943 -0.547167 -1.692824 -0.630589  0.166632  0.676244
# 33899  2102983  -2.036832 -0.153534  0.162852  0.082651 -0.126419  0.255109
# 33900  2103039  -2.036832 -0.153534  0.162852  0.082651 -0.126419  0.255109
#
#               6         7         8
# 0      0.681042  2.312613  0.868272
# 1      0.549769  0.469033  0.033405
# 2      1.677582  2.937669  2.097639
# 3      0.030956  0.039519  0.210887
# 4      0.118559  0.559292  0.186379
# ...         ...       ...       ...
# 33896  1.752049  1.486542 -0.523600
# 33897  0.046413  0.191709  0.260437
# 33898 -0.055100  0.582091  1.703193
# 33899  0.072496  0.113750  0.622900
# 33900  0.072496  0.113750  0.622900
#
# [33901 rows x 10 columns]

# %%
new_df. columns = ['user'] + [f'PC{i}' for i in range(9)]
new_df
# Out:
#           user        PC0       PC1       PC2       PC3       PC4       PC5  \
# 0            2  17.772494  0.200681  1.730609  2.567359 -3.825814  2.707154
# 1            4   7.145199 -2.847481  2.358636 -0.576654  0.398803 -0.134533
# 2            5  11.363270  1.873619 -1.522077  1.076144 -1.711688  0.883212
# 3            7  -1.834033 -0.277462  0.564905  0.053470 -0.064440  0.165757
# 4            8  -1.049125 -0.684767  1.072765  0.006371 -0.005695  0.118686
# ...        ...        ...       ...       ...       ...       ...       ...
# 33896  2102054   0.633824  0.108815 -0.388871 -0.122665 -0.098364  0.358333
# 33897  2102356  -2.095339  0.135058  0.244727 -0.088185  0.025081  0.183641
# 33898  2102680   0.625943 -0.547167 -1.692824 -0.630589  0.166632  0.676244
# 33899  2102983  -2.036832 -0.153534  0.162852  0.082651 -0.126419  0.255109
# 33900  2103039  -2.036832 -0.153534  0.162852  0.082651 -0.126419  0.255109
#
#             PC6       PC7       PC8
# 0      0.681042  2.312613  0.868272
# 1      0.549769  0.469033  0.033405
# 2      1.677582  2.937669  2.097639
# 3      0.030956  0.039519  0.210887
# 4      0.118559  0.559292  0.186379
# ...         ...       ...       ...
# 33896  1.752049  1.486542 -0.523600
# 33897  0.046413  0.191709  0.260437
# 33898 -0.055100  0.582091  1.703193
# 33899  0.072496  0.113750  0.622900
# 33900  0.072496  0.113750  0.622900
#
# [33901 rows x 10 columns]

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * Call PCA class as `pca = PCA(n_components=n_components)`
# * Fit PCA model using predefined `features` variable as only parameter
# * Get the components by calling `pca.fit_transform(features)`
# * Create a `pd.DataFrame(data=components)` and use `pd.merge` to merge it with `user_ids` don't forget to specify `left_index=True, right_index=True` in `merge` function parameters.
#
# </details>

# %% [markdown]
# Your PCA transformed dataframe may look like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/pca_res.png)

# %% [markdown]
# ### TASK: Perform k-means clustering on the PCA transformed feature vectors

# %% [markdown]
# Now, you have the PCA  components of the original profile vectors. You can perform k-means on them again:

# %% [markdown]
# _TODO: Perform K-means on the PCA transformed features_

# %%
## WRITE YOUR CODE HERE

## - Apply KMeans() on the PCA features
## - Obtain the cluster label lists from model.labels_ attribute
## - Assign each user a cluster label by combining user ids and cluster labels
distorsions = []
for k in range(1, 30):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(transformed_features)
    distorsions.append(kmeans.inertia_)

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(range(1, 30), distorsions)
plt.grid(True)
plt.title('Elbow curve')
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %%
kmeans = KMeans(n_clusters=25)
kmeans.fit(transformed_features)
# Out:
# KMeans(n_clusters=25)

# %%
cluster_labels = kmeans.labels_
cluster_labels.shape
# Out:
# (33901,)

# %%
cluster_df = combine_cluster_labels(user_ids, cluster_labels)
cluster_df
# Out:
#           user  cluster
# 0            2       10
# 1            4       17
# 2            5       10
# 3            7        5
# 4            8       24
# ...        ...      ...
# 33896  2102054       12
# 33897  2102356        5
# 33898  2102680        7
# 33899  2102983        5
# 33900  2103039        5
#
# [33901 rows x 2 columns]

# %% [markdown]
# Your clustering results should have the same format as the k-means on the original dataset:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/cluster_labels.png)

# %% [markdown]
# Great, now all users find their learning interest groups, either based on their original or the PCA transformed user profile features.

# %% [markdown]
# When a user is in a group or a community, it is very likely that the user will be interested in the courses enrolled by other members within the same group.

# %% [markdown]
# ### TASK: Generate course recommendations based on the popular courses in the same cluster

# %% [markdown]
# The Intuition of clustering-based course recommendation is very simple and can be illustrated via the following example:

# %% [markdown]
# Suppose a user has joined a machine learning group (via clustering algorithm). In the group, he/she finds that the top-3 courses enrolled by all other group members are `Machine Learning for Everyone`, `Machine Learning with Python`, `Machine Learning with Scikit-learn`. Since the user has already completed the `Machine Learning for Everyone` earlier, he/she decides to trust the group members' choices and enroll in other two unselected courses `Machine Learning with Python` and `Machine Learning with Scikit-learn`.

# %% [markdown]
# In summary, the clustering-based recommender system first groups all users based on their profiles, and maintains a popular courses list for each group.
#
# For any group member who needs course recommendations, the algorithm recommends the unselected courses from the popular course lists.

# %% [markdown]
# Next, suppose we have a set of test users, and we want to recommend new courses to them using a clustering-based recommender system:

# %%
test_user_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/rs_content_test.csv"

# Reading the test user data CSV file into a pandas DataFrame
# Selecting only the 'user' and 'item' columns using indexing
test_users_df = pd.read_csv(test_user_url)[['user', 'item']]

# Displaying the first few rows of the DataFrame to inspect its contents
test_users_df.head()
# Out:
#       user      item
# 0  1502801  RP0105EN
# 1  1609720  CNSC02EN
# 2  1347188  CO0301EN
# 3   755067  ML0103EN
# 4   538595  BD0115EN

# %% [markdown]
# The test users dataset has only two columns, the user id and the enrolled course id.

# %% [markdown]
# For each user, let's find its cluster label using the k-means results you have performed in previous steps, assuming it is named `cluster_df`.

# %% [markdown]
# You can assign the cluster label to all test users via merging the clustering labels (`cluster_df`:):

# %%
test_users_labelled = pd.merge(test_users_df, cluster_df, left_on='user', right_on='user')
test_users_labelled
# Out:
#          user       item  cluster
# 0     1502801   RP0105EN        3
# 1     1609720   CNSC02EN        7
# 2     1347188   CO0301EN        9
# 3      755067   ML0103EN       24
# 4      538595   BD0115EN        3
# ...       ...        ...      ...
# 9397  1385217   EE0101EN       20
# 9398  1864644   DA0101EN        7
# 9399   435858  TMP0105EN        5
# 9400  1888188   DB0101EN        4
# 9401   708518   RP0101EN       15
#
# [9402 rows x 3 columns]

# %% [markdown]
# The merged the test dataset may look like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/test_users_label.png)

# %% [markdown]
# From the above dataframe, we know each user's enrolled courses and its cluster index.

# %% [markdown]
# If we use a `groupby`  and `sum` aggregation, we can get the enrollments count for each course in each group, like the following code snippet:

# %%
# Extracting the 'item' and 'cluster' columns from the test_users_labelled DataFrame
courses_cluster = test_users_labelled[['item', 'cluster']]

# Adding a new column 'count' with a value of 1 for each row in the courses_cluster DataFrame
courses_cluster['count'] = [1] * len(courses_cluster)

# Grouping the DataFrame by 'cluster' and 'item', aggregating the 'count' column with the sum function,
# and resetting the index to make the result more readable
courses_cluster_grouped = courses_cluster.groupby(['cluster','item']).agg(enrollments=('count','sum')).reset_index()
courses_cluster_grouped
# Out:
#       cluster      item  enrollments
# 0           0  BD0101EN           19
# 1           0  BD0111EN           14
# 2           0  BD0115EN            1
# 3           0  BD0123EN            3
# 4           0  BD0135EN            1
# ...       ...       ...          ...
# 1399       24  SC0103EN            7
# 1400       24  SC0105EN            2
# 1401       24  ST0101EN           10
# 1402       24    TA0105            3
# 1403       24  WA0101EN            9
#
# [1404 rows x 3 columns]

# %%
courses_cluster = test_users_labelled[['item', 'cluster']]
courses_cluster['count'] = [1] * len(courses_cluster)
count_enrollments_df = courses_cluster.groupby(['cluster','item']).agg(enrollments = ('count','sum')).reset_index()
count_enrollments_df
# Out:
#       cluster      item  enrollments
# 0           0  BD0101EN           19
# 1           0  BD0111EN           14
# 2           0  BD0115EN            1
# 3           0  BD0123EN            3
# 4           0  BD0135EN            1
# ...       ...       ...          ...
# 1399       24  SC0103EN            7
# 1400       24  SC0105EN            2
# 1401       24  ST0101EN           10
# 1402       24    TA0105            3
# 1403       24  WA0101EN            9
#
# [1404 rows x 3 columns]

# %% [markdown]
# _TODO: For each test user, try to recommend any unseen courses based on the popular courses in his/her cluster. You may use an enrollment count threshold (such as larger than 10) to determine if it is a popular course in the cluster_

# %%
## WRITE YOUR CODE HERE

## - For each user, first finds its cluster label

    ## - First get all courses belonging to the same cluster and figure out what are the popular ones (such as course enrollments beyond a threshold like 100)
    
    ## - Get the user's current enrolled courses
    
    ## - Check if there are any courses on the popular course list which are new/unseen to the user. 
    
    ## If yes, make those unseen and popular courses as recommendation results for the user
popular_courses_by_cluster = {}
for i in range(25):
    tmp_df = count_enrollments_df[count_enrollments_df['cluster']==i]
    tmp_df.sort_values(by=['enrollments'], ascending=False, inplace=True)
    popular_courses_by_cluster[i] = tmp_df['item'].values[:3]
    # print(tmp_df.values[:3])
    print(f'user in cluster {i} will be sugessted 3 courses as {popular_courses_by_cluster[i]}')
    
for index, row in test_users_labelled.iterrows():
    user = row['user']
    cluster = row['cluster']
    print(f'user {user} in cluster {cluster} is recommened 3 courses as {popular_courses_by_cluster[cluster][:3]}')
# Out:
# /tmp/ipykernel_81/770962899.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df.sort_values(by=['enrollments'], ascending=False, inplace=True)
# user in cluster 0 will be sugessted 3 courses as ['CO0101EN' 'PY0101EN' 'CC0101EN']
# user in cluster 1 will be sugessted 3 courses as ['PY0101EN' 'DS0101EN' 'DS0103EN']
# user in cluster 2 will be sugessted 3 courses as ['BC0101EN' 'CB0103EN' 'PY0101EN']
# user in cluster 3 will be sugessted 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user in cluster 4 will be sugessted 3 courses as ['CO0301EN' 'CO0201EN' 'BC0101EN']
# user in cluster 5 will be sugessted 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user in cluster 6 will be sugessted 3 courses as []
# user in cluster 7 will be sugessted 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user in cluster 8 will be sugessted 3 courses as ['CO0101EN' 'CO0401EN' 'CO0301EN']
# user in cluster 9 will be sugessted 3 courses as ['BC0101EN' 'CO0101EN' 'CC0101EN']
# user in cluster 10 will be sugessted 3 courses as ['BD0101EN' 'BD0111EN' 'BD0131EN']
# user in cluster 11 will be sugessted 3 courses as ['PY0101EN' 'CB0103EN' 'DS0101EN']
# user in cluster 12 will be sugessted 3 courses as ['RP0101EN' 'DS0101EN' 'DS0103EN']
# user in cluster 13 will be sugessted 3 courses as ['CO0101EN' 'CO0201EN' 'CO0301EN']
# user in cluster 14 will be sugessted 3 courses as ['BD0101EN' 'CO0101EN' 'BD0211EN']
# user in cluster 15 will be sugessted 3 courses as ['DS0101EN' 'RP0101EN' 'DS0103EN']
# user in cluster 16 will be sugessted 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user in cluster 17 will be sugessted 3 courses as ['BD0111EN' 'BD0211EN' 'BD0223EN']
# user in cluster 18 will be sugessted 3 courses as ['LB0101ENv1' 'LB0103ENv1' 'LB0105ENv1']
# user in cluster 19 will be sugessted 3 courses as ['CB0103EN' 'DS0101EN' 'BD0101EN']
# user in cluster 20 will be sugessted 3 courses as ['BD0111EN' 'BD0115EN' 'BD0211EN']
# user in cluster 21 will be sugessted 3 courses as ['BC0101EN' 'BD0101EN' 'DS0101EN']
# user in cluster 22 will be sugessted 3 courses as ['CB0103EN' 'PY0101EN' 'DA0101EN']
# user in cluster 23 will be sugessted 3 courses as ['BC0101EN' 'BC0201EN' 'PY0101EN']
# user in cluster 24 will be sugessted 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1502801 in cluster 3 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user 1609720 in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 1347188 in cluster 9 is recommened 3 courses as ['BC0101EN' 'CO0101EN' 'CC0101EN']
# user 755067 in cluster 24 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 538595 in cluster 3 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user 1773079 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 603361 in cluster 9 is recommened 3 courses as ['BC0101EN' 'CO0101EN' 'CC0101EN']
# user 1122903 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 714414 in cluster 2 is recommened 3 courses as ['BC0101EN' 'CB0103EN' 'PY0101EN']
# user 1688159 in cluster 18 is recommened 3 courses as ['LB0101ENv1' 'LB0103ENv1' 'LB0105ENv1']
# user 703905 in cluster 23 is recommened 3 courses as ['BC0101EN' 'BC0201EN' 'PY0101EN']
# user 881847 in cluster 11 is recommened 3 courses as ['PY0101EN' 'CB0103EN' 'DS0101EN']
# user 1784245 in cluster 14 is recommened 3 courses as ['BD0101EN' 'CO0101EN' 'BD0211EN']
# user 1443131 in cluster 16 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1773434 in cluster 4 is recommened 3 courses as ['CO0301EN' 'CO0201EN' 'BC0101EN']
# user 489692 in cluster 8 is recommened 3 courses as ['CO0101EN' 'CO0401EN' 'CO0301EN']
# user 430274 in cluster 19 is recommened 3 courses as ['CB0103EN' 'DS0101EN' 'BD0101EN']
# user 1394499 in cluster 17 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0223EN']
# user 1221910 in cluster 21 is recommened 3 courses as ['BC0101EN' 'BD0101EN' 'DS0101EN']
# user 1636610 in cluster 21 is recommened 3 courses as ['BC0101EN' 'BD0101EN' 'DS0101EN']
# user 1504635 in cluster 0 is recommened 3 courses as ['CO0101EN' 'PY0101EN' 'CC0101EN']
# user 616284 in cluster 19 is recommened 3 courses as ['CB0103EN' 'DS0101EN' 'BD0101EN']
# user 462755 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 902138 in cluster 3 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user 1102170 in cluster 9 is recommened 3 courses as ['BC0101EN' 'CO0101EN' 'CC0101EN']
# user 510780 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 220851 in cluster 19 is recommened 3 courses as ['CB0103EN' 'DS0101EN' 'BD0101EN']
# user 952742 in cluster 11 is recommened 3 courses as ['PY0101EN' 'CB0103EN' 'DS0101EN']
# user 704521 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 517197 in cluster 11 is recommened 3 courses as ['PY0101EN' 'CB0103EN' 'DS0101EN']
# user 1806207 in cluster 1 is recommened 3 courses as ['PY0101EN' 'DS0101EN' 'DS0103EN']
# user 1648099 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 108541 in cluster 24 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1642918 in cluster 15 is recommened 3 courses as ['DS0101EN' 'RP0101EN' 'DS0103EN']
# user 601371 in cluster 12 is recommened 3 courses as ['RP0101EN' 'DS0101EN' 'DS0103EN']
# user 1199884 in cluster 12 is recommened 3 courses as ['RP0101EN' 'DS0101EN' 'DS0103EN']
# user 531408 in cluster 12 is recommened 3 courses as ['RP0101EN' 'DS0101EN' 'DS0103EN']
# user 708518 in cluster 15 is recommened 3 courses as ['DS0101EN' 'RP0101EN' 'DS0103EN']
# user 1351020 in cluster 1 is recommened 3 courses as ['PY0101EN' 'DS0101EN' 'DS0103EN']
# user 472908 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 482875 in cluster 16 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1541383 in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 877026 in cluster 1 is recommened 3 courses as ['PY0101EN' 'DS0101EN' 'DS0103EN']
# user 755044 in cluster 16 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 913275 in cluster 3 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user 1275452 in cluster 22 is recommened 3 courses as ['CB0103EN' 'PY0101EN' 'DA0101EN']
# user 985429 in cluster 16 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1237626 in cluster 1 is recommened 3 courses as ['PY0101EN' 'DS0101EN' 'DS0103EN']
# user 577001 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 981848 in cluster 15 is recommened 3 courses as ['DS0101EN' 'RP0101EN' 'DS0103EN']
# user 1751931 in cluster 22 is recommened 3 courses as ['CB0103EN' 'PY0101EN' 'DA0101EN']
# user 1378699 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 705065 in cluster 9 is recommened 3 courses as ['BC0101EN' 'CO0101EN' 'CC0101EN']
# user 462755 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 1452505 in cluster 0 is recommened 3 courses as ['CO0101EN' 'PY0101EN' 'CC0101EN']
# user 705065 in cluster 9 is recommened 3 courses as ['BC0101EN' 'CO0101EN' 'CC0101EN']
# user 762860 in cluster 16 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1571271 in cluster 22 is recommened 3 courses as ['CB0103EN' 'PY0101EN' 'DA0101EN']
# user 767649 in cluster 4 is recommened 3 courses as ['CO0301EN' 'CO0201EN' 'BC0101EN']
# user 1194679 in cluster 3 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user 1882084 in cluster 16 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1506139 in cluster 2 is recommened 3 courses as ['BC0101EN' 'CB0103EN' 'PY0101EN']
# user 569052 in cluster 24 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1316258 in cluster 13 is recommened 3 courses as ['CO0101EN' 'CO0201EN' 'CO0301EN']
# user 1016747 in cluster 3 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user 696345 in cluster 19 is recommened 3 courses as ['CB0103EN' 'DS0101EN' 'BD0101EN']
# user
in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 1396267 in cluster 21 is recommened 3 courses as ['BC0101EN' 'BD0101EN' 'DS0101EN']
# user 1078030 in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 1236864 in cluster 3 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user 753356 in cluster 16 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 506202 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 889030 in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 1699356 in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 1177066 in cluster 24 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1773434 in cluster 4 is recommened 3 courses as ['CO0301EN' 'CO0201EN' 'BC0101EN']
# user 992171 in cluster 22 is recommened 3 courses as ['CB0103EN' 'PY0101EN' 'DA0101EN']
# user 266643 in cluster 0 is recommened 3 courses as ['CO0101EN' 'PY0101EN' 'CC0101EN']
# user 1570208 in cluster 24 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1342117 in cluster 14 is recommened 3 courses as ['BD0101EN' 'CO0101EN' 'BD0211EN']
# user 1646441 in cluster 23 is recommened 3 courses as ['BC0101EN' 'BC0201EN' 'PY0101EN']
# user 37465 in cluster 24 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1808215 in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 1155304 in cluster 13 is recommened 3 courses as ['CO0101EN' 'CO0201EN' 'CO0301EN']
# user 1228256 in cluster 22 is recommened 3 courses as ['CB0103EN' 'PY0101EN' 'DA0101EN']
# user 784838 in cluster 3 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user 1029144 in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 1627595 in cluster 22 is recommened 3 courses as ['CB0103EN' 'PY0101EN' 'DA0101EN']
# user 1242036 in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 1120306 in cluster 14 is recommened 3 courses as ['BD0101EN' 'CO0101EN' 'BD0211EN']
# user 896335 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 2032910 in cluster 22 is recommened 3 courses as ['CB0103EN' 'PY0101EN' 'DA0101EN']
# user 406940 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 1049634 in cluster 23 is recommened 3 courses as ['BC0101EN' 'BC0201EN' 'PY0101EN']
# user 1256661 in cluster 9 is recommened 3 courses as ['BC0101EN' 'CO0101EN' 'CC0101EN']
# user 741200 in cluster 23 is recommened 3 courses as ['BC0101EN' 'BC0201EN' 'PY0101EN']
# user 1342117 in cluster 14 is recommened 3 courses as ['BD0101EN' 'CO0101EN' 'BD0211EN']
# user 655195 in cluster 8 is recommened 3 courses as ['CO0101EN' 'CO0401EN' 'CO0301EN']
# user 1131617 in cluster 14 is recommened 3 courses as ['BD0101EN' 'CO0101EN' 'BD0211EN']
# user 1919394 in cluster 18 is recommened 3 courses as ['LB0101ENv1' 'LB0103ENv1' 'LB0105ENv1']
# user 748522 in cluster 16 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 352684 in cluster 15 is recommened 3 courses as ['DS0101EN' 'RP0101EN' 'DS0103EN']
# user 553969 in cluster 3 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user 1655079 in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 750374 in cluster 4 is recommened 3 courses as ['CO0301EN' 'CO0201EN' 'BC0101EN']
# user 771772 in cluster 12 is recommened 3 courses as ['RP0101EN' 'DS0101EN' 'DS0103EN']
# user 1889420 in cluster 1 is recommened 3 courses as ['PY0101EN' 'DS0101EN' 'DS0103EN']
# user 940704 in cluster 15 is recommened 3 courses as ['DS0101EN' 'RP0101EN' 'DS0103EN']
# user 728690 in cluster 16 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 779857 in cluster 22 is recommened 3 courses as ['CB0103EN' 'PY0101EN' 'DA0101EN']
# user 1411341 in cluster 22 is recommened 3 courses as ['CB0103EN' 'PY0101EN' 'DA0101EN']
# user 983498 in cluster 23 is recommened 3 courses as ['BC0101EN' 'BC0201EN' 'PY0101EN']
# user 703905 in cluster 23 is recommened 3 courses as ['BC0101EN' 'BC0201EN' 'PY0101EN']
# user 1468497 in cluster 13 is recommened 3 courses as ['CO0101EN' 'CO0201EN' 'CO0301EN']
# user 1474724 in cluster 24 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 553969 in cluster 3 is recommened 3 courses as ['BD0111EN' 'BD0211EN' 'BD0101EN']
# user 510780 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 666633 in cluster 24 is recommened 3 courses as ['BD0101EN' 'BD0111EN' 'BD0211EN']
# user 1385217 in cluster 20 is recommened 3 courses as ['BD0111EN' 'BD0115EN' 'BD0211EN']
# user 1864644 in cluster 7 is recommened 3 courses as ['PY0101EN' 'ML0101ENv3' 'DA0101EN']
# user 435858 in cluster 5 is recommened 3 courses as ['DS0101EN' 'BD0101EN' 'PY0101EN']
# user 1888188 in cluster 4 is recommened 3 courses as ['CO0301EN' 'CO0201EN' 'BC0101EN']
# user 708518 in cluster 15 is recommened 3 courses as ['DS0101EN' 'RP0101EN' 'DS0103EN']

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * First of all, create a `user_subset` of  `test_users_labelled` where `test_users_labelled['user'] == user_id`.
# * Get the enrolled courses by  simply accessing `['item']` column of `user_subset`
# * Find its cluster label by accessing `['cluster']` column of `user_subset`. You can just use the first one (`.iloc[0]`) since every value in the column is the same for an individual user.
# * You can find all courses in the same cluster, by simply accessing `['item']` column of a subset of `test_users_labelled` where `test_users_labelled[test_users_labelled['cluster'] == cluster_id]`
# * You can find new/unseen courses to the user by taking a set difference between courses in cluster and enrolled_courses by using `.difference` method (dont forget to convert 2 lists in to sets before calling the method).
# * Use `courses_cluster` data set to find popularity of new/unseen courses and make unseen and popular courses as recommendation results for the user
#
# </details>

# %% [markdown]
# With the recommendation results, you also need to write some analytic code to answer the following two questions:

# %% [markdown]
# - On average, how many new/unseen courses have been recommended to each user?
# - What are the most frequently recommended courses? Return the top-10 commonly recommended courses across all users.

# %% [markdown]
# For example, suppose we have only 3 test users, each user receives the following recommendations:

# %% [markdown]
# - User1: ['course1', 'course2']
# - User2: ['course3', 'course4']
# - User3: ['course3', 'course4', 'course5']

# %% [markdown]
# Then, the average recommended courses per user is $(2 + 2 + 3) / 3 = 2.33$. The top-2 recommended courses are: `course3`: 2 times, and `course4`: 2 times.

# %% [markdown]
# Note that the answers will depend on how you compute the popular courses for each cluster. A lower threshold yields more recommended courses but with smaller confidence so that some test users may receive very long course recommendation lists and feel overwhelmed.
#
# Ideally, we should limit the maximum course recommendations for each user to be less than 20 courses per user.

# %% [markdown]
# ### Explore other clustering algorithms

# %% [markdown]
# As you have learned in previous unsupervised learning course, there are many other clustering algorithms such as `DBSCAN` and `Hierarchical Clustering`. You are encouraged to try them on the user profile feature vectors and compare the results with K-means.

# %% [markdown]
# ### Summary

# %% [markdown]
# Congratulations! In this lab, you have applied clustering algorithms to group users with similar interests and also tried PCA to reduce the dimensions of user feature vectors.
#
# Furthermore, with each user finding its learning interest group, you have also implemented clustering-based course recommender system to make recommendations based on his/her group members' popular courses choices.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Yan Luo]((https://www.linkedin.com/in/yan-luo-96288783/)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ```toggle## Change Log
# ```

# %% [markdown]
# ```toggle|Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# ```
# ```toggle|-|-|-|-|
# ```
# ```toggle|2021-10-25|1.0|Yan|Created the initial version|
# ```

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
